# %% [markdown]
# ## Dataset
# | Column Name              | الوصف بالعربي                   | Possible Values                                                                                                                 |
# | ------------------------ | ------------------------------- | ------------------------------------------------------------------------------------------------------------------------------- |
# | **class**                | نوع المشروم (الهدف)             | e = edible, p = poisonous                                                                                                       |
# | **cap-diameter**         | قطر قبعة المشروم                | Continuous values (e.g., 2.0 – 20.0)                                                                                            |
# | **cap-shape**            | شكل القبعة                      | b = bell, c = conical, x = convex, f = flat, s = sunken, p = spherical, o = others                                              |
# | **cap-surface**          | ملمس سطح القبعة                 | s = smooth, y = scaly, h = shiny, g = grooves, k = silky, t = sticky                                                            |
# | **cap-color**            | لون القبعة                      | n = brown, b = buff, g = gray, r = green, p = pink, u = purple, e = red, w = white, y = yellow, l = blue, o = orange, k = black |
# | **does-bruise-or-bleed** | هل يتغير لونه أو ينزف عند الضغط | t = true, f = false                                                                                                             |
# | **gill-attachment**      | طريقة اتصال الخياشيم بالساق     | a = attached, x = free, d = decurrent, e = notched, s = sinuate                                                                 |
# | **gill-spacing**         | المسافة بين الخياشيم            | c = close, d = distant, w = crowded                                                                                             |
# | **gill-color**           | لون الخياشيم                    | Same as cap-color codes                                                                                                         |
# | **stem-height**          | طول الساق                       | Continuous values                                                                                                               |
# | **stem-width**           | عرض الساق                       | Continuous values                                                                                                               |
# | **stem-root**            | نوع جذر الساق                   | b = bulbous, s = swollen, c = club, u = cup, e = equal, z = rhizomorphs, r = rooted                                             |
# | **stem-surface**         | ملمس سطح الساق                  | s = smooth, y = scaly, h = hairy, g = grooves, k = silky                                                                        |
# | **stem-color**           | لون الساق                       | Same as cap-color codes                                                                                                         |
# | **veil-type**            | نوع الغشاء                      | p = partial, u = universal                                                                                                      |
# | **veil-color**           | لون الغشاء                      | Same as cap-color codes                                                                                                         |
# | **has-ring**             | وجود حلقة حول الساق             | t = true, f = false                                                                                                             |
# | **ring-type**            | نوع الحلقة                      | e = evanescent, f = flaring, g = grooved, l = large, p = pendant, s = sheathing, z = zone                                       |
# | **spore-print-color**    | لون الجراثيم                    | Same as cap-color codes                                                                                                         |
# | **habitat**              | البيئة أو الموطن                | g = grasses, l = leaves, m = meadows, p = paths, u = urban, w = waste, d = woods                                                |
# | **season**               | الموسم                          | s = spring, u = summer, a = autumn, w = winter                                                                                  |

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
"""balanced_df = (
    df.groupby('class', group_keys=False)
      .apply(lambda x: x.sample(frac=0.3, random_state=42))
      .reset_index(drop=True)
)"""

# %%
"""balanced_df.to_csv("balanced_mushroom_sample.csv", index=False)"""

# %%
df=  pd.read_csv("balanced_mushroom_sample.csv")

# %%
df.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     e          3.85         f           s         w                    f
# 1     e          5.48         p         NaN         g                    f
# 2     e          9.60         x           s         n                    t
# 3     e          8.74         x           s         n                    t
# 4     e         10.86         s           t         w                    t
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               d            d          w         3.81  ...        NaN
# 1               f            f          f         5.14  ...        NaN
# 2               p          NaN          n         7.45  ...        NaN
# 3               p          NaN          n         7.00  ...        NaN
# 4               d            c          o         5.73  ...        NaN
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# ...

# %%
df.tail()
# Out:
#        class  cap-diameter cap-shape cap-surface cap-color  \
# 935079     p          2.03         b           g         y
# 935080     p         12.44         x           t         n
# 935081     p          4.74         x           s         e
# 935082     p          8.21         x           e         n
# 935083     p          7.37         s           t         y
#
#        does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 935079                    f             NaN            c          n
# 935080                    t               d            c          n
# 935081                    f               a            c          y
# 935082                    f               a          NaN          n
# 935083                    f               x            c          y
#
#         stem-height  ...  stem-root stem-surface stem-color veil-type  \
# 935079         6.40  ...        NaN          NaN          n       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935084 entries, 0 to 935083
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   class                 935084 non-null  object
#  1   cap-diameter          935083 non-null  float64
#  2   cap-shape             935075 non-null  object
#  3   cap-surface           733553 non-null  object
#  4   cap-color             935081 non-null  object
#  5   does-bruise-or-bleed  935081 non-null  object
#  6   gill-attachment       777337 non-null  object
#  7   gill-spacing          557798 non-null  object
#  8   gill-color            935074 non-null  object
#  9   stem-height           935084 non-null  float64
#  10  stem-width            935084 non-null  float64
#  11  stem-root             108224 non-null  object
#  12  stem-surface          341271 non-null  object
#  13  stem-color            935076 non-null  object
# ...

# %%
df.shape
# Out:
# (935084, 21)

# %%
df.isnull().sum().sort_values()
# Out:
# class                        0
# stem-height                  0
# stem-width                   0
# season                       0
# cap-diameter                 1
# cap-color                    3
# does-bruise-or-bleed         3
# has-ring                     7
# stem-color                   8
# cap-shape                    9
# gill-color                  10
# habitat                     13
# ring-type                38901
# gill-attachment         157747
# cap-surface             201531
# gill-spacing            377286
# stem-surface            593813
# veil-color              822181
# stem-root               826860
# spore-print-color       854553
# veil-type               887244
# dtype: int64

# %%
df.isnull().sum().sort_values()/len(df)*100
# Out:
# class                    0.000000
# stem-height              0.000000
# stem-width               0.000000
# season                   0.000000
# cap-diameter             0.000107
# cap-color                0.000321
# does-bruise-or-bleed     0.000321
# has-ring                 0.000749
# stem-color               0.000856
# cap-shape                0.000962
# gill-color               0.001069
# habitat                  0.001390
# ring-type                4.160161
# gill-attachment         16.869821
# cap-surface             21.552181
# gill-spacing            40.347819
# stem-surface            63.503707
# veil-color              87.925898
# stem-root               88.426280
# spore-print-color       91.387833
# veil-type               94.883882
# dtype: float64

# %%
sns.countplot(x="does-bruise-or-bleed", data=df)
plt.title("Class Distribution")
plt.xlabel("Does Bruise or Bleed")
plt.ylabel("Count")
plt.show()

# %% [markdown]
#  ## preprocessing

# %%
df.drop(['veil-type' ,'spore-print-color' , 'stem-root' , 'veil-color' , 'stem-surface' , 'gill-spacing' ] , axis=1  , inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 935084 entries, 0 to 935083
# Data columns (total 15 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   class                 935084 non-null  object
#  1   cap-diameter          935083 non-null  float64
#  2   cap-shape             935075 non-null  object
#  3   cap-surface           733553 non-null  object
#  4   cap-color             935081 non-null  object
#  5   does-bruise-or-bleed  935081 non-null  object
#  6   gill-attachment       777337 non-null  object
#  7   gill-color            935074 non-null  object
#  8   stem-height           935084 non-null  float64
#  9   stem-width            935084 non-null  float64
#  10  stem-color            935076 non-null  object
#  11  has-ring              935077 non-null  object
#  12  ring-type             896183 non-null  object
#  13  habitat               935071 non-null  object
# ...

# %%
df.duplicated().sum()
# Out:
# 51

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder , OneHotEncoder

# %%
lab_encode= LabelEncoder()
df['class'] = lab_encode.fit_transform(df[["class"]])

# %%
cap_shape_map = {
    'b': 'bell',
    'c': 'conical',
    'x': 'convex',
    'f': 'flat',
    's': 'sunken',
    'p': 'spherical',
    'o': 'others'
}

cap_color_map = {
    'n': 'brown', 'b': 'buff', 'g': 'gray', 'r': 'green',
    'p': 'pink', 'u': 'purple', 'e': 'red', 'w': 'white',
    'y': 'yellow', 'l': 'blue', 'o': 'orange', 'k': 'black'
}

bruise_map = {'t': 'true', 'f': 'false'}

habitat_map = {
    'g': 'grasses', 'l': 'leaves', 'm': 'meadows',
    'p': 'paths', 'u': 'urban', 'w': 'waste', 'd': 'woods'
}

season_map = {
    's': 'spring', 'u': 'summer', 'a': 'autumn', 'w': 'winter'
}

# %%
df['cap-shape'] = df['cap-shape'].map(cap_shape_map)
df['cap-color'] = df['cap-color'].map(cap_color_map)
df['gill-color'] = df['gill-color'].map(cap_color_map)
df['stem-color'] = df['stem-color'].map(cap_color_map)
df['does-bruise-or-bleed'] = df['does-bruise-or-bleed'].map(bruise_map)
df['has-ring'] = df['has-ring'].map(bruise_map)
df['habitat'] = df['habitat'].map(habitat_map)
df['season'] = df['season'].map(season_map)

# %%
df = pd.get_dummies(df, columns=[
    'cap-shape',
    'cap-color',
    'gill-color',
    'stem-color',
    'does-bruise-or-bleed',
    'has-ring',
    'habitat',
    'season'
])

# %%
sns.countplot(x='class', data=df, palette='Set2')
plt.title("Class Distribution")
plt.show()

# %%
sns.histplot(x="cap-diameter", data=df)
plt.title("Cap Diameter Distribution")
plt.xlabel("Cap Diameter")
plt.ylabel("Count")
plt.show()

# %%
sns.histplot(data=df, x="cap-diameter", hue="class", bins=20)
plt.suptitle("Cap Diameter Distribution by Class")
plt.show()

# %%
df.boxplot(column="cap-diameter", by="class")
plt.title("Cap Diameter by Class")
plt.xlabel("Class")
plt.ylabel("Cap Diameter")
plt.show()

# %% [markdown]
# ####

# %%
from sklearn.impute import SimpleImputer

# %%
impute = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df['cap-surface'] = impute.fit_transform(df[['cap-surface']]).ravel()
df["cap-surface"] = lab_encode.fit_transform(df[['cap-surface']])

# %%
df["gill-attachment"] = lab_encode.fit_transform(df[["gill-attachment"]])

# %%
from sklearn.impute import KNNImputer

# %%
knn_imputer=KNNImputer(missing_values=np.nan, n_neighbors=10)

# %%
df[['gill-attachment']] = knn_imputer.fit_transform(df[['gill-attachment']])

# %%
df["ring-type"] = lab_encode.fit_transform(df['ring-type'])
df[['ring-type']] = knn_imputer.fit_transform(df[['ring-type']])

# %%
df.isnull().sum().sort_values()
df.dropna(inplace=True)
df.isnull().sum().sort_values()
# Out:
# class              0
# cap-diameter       0
# cap-surface        0
# gill-attachment    0
# stem-height        0
#                   ..
# habitat_woods      0
# season_autumn      0
# season_spring      0
# season_summer      0
# season_winter      0
# Length: 65, dtype: int64

# %%
x=df.drop(["class"] , axis= 1 )
y= df["class"]

# %%
x = x.reset_index(drop=True)
y = y.reset_index(drop=True)

# %%
print(x.shape)
print(y.shape)
# Out:
# (935032, 64)
# (935032,)

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_classif

# %%
df.columns
# Out:
# Index(['class', 'cap-diameter', 'cap-surface', 'gill-attachment',
#        'stem-height', 'stem-width', 'ring-type', 'cap-shape_bell',
#        'cap-shape_conical', 'cap-shape_convex', 'cap-shape_flat',
#        'cap-shape_others', 'cap-shape_spherical', 'cap-shape_sunken',
#        'cap-color_black', 'cap-color_blue', 'cap-color_brown',
#        'cap-color_buff', 'cap-color_gray', 'cap-color_green',
#        'cap-color_orange', 'cap-color_pink', 'cap-color_purple',
#        'cap-color_red', 'cap-color_white', 'cap-color_yellow',
#        'gill-color_black', 'gill-color_blue', 'gill-color_brown',
#        'gill-color_buff', 'gill-color_gray', 'gill-color_green',
#        'gill-color_orange', 'gill-color_pink', 'gill-color_purple',
#        'gill-color_red', 'gill-color_white', 'gill-color_yellow',
#        'stem-color_black', 'stem-color_blue', 'stem-color_brown',
#        'stem-color_buff', 'stem-color_gray', 'stem-color_green',
# ...

# %%
x.columns = x.columns.astype(str)
selector = SelectKBest(score_func=mutual_info_classif, k=19)
X_new= selector.fit_transform(x, y)
selected_features = x.columns[selector.get_support()]

selected_features
# Out:
# Index(['cap-diameter', 'cap-surface', 'gill-attachment', 'stem-height',
#        'stem-width', 'ring-type', 'cap-shape_bell', 'cap-shape_convex',
#        'cap-color_brown', 'gill-color_brown', 'gill-color_white',
#        'stem-color_brown', 'stem-color_white', 'does-bruise-or-bleed_false',
#        'has-ring_false', 'has-ring_true', 'habitat_woods', 'season_autumn',
#        'season_summer'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
x= df[selected_features]
y= df["class"]
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=42)

# %%
X_new = pd.DataFrame(X_new, columns=selected_features)

# %%
plt.figure(figsize=(24,16))
sns.heatmap(X_new.corr() , annot=True , fmt='.2f')
plt.xticks(rotation=45, ha="right")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)
KNeighborsClassifier()
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    balanced_accuracy_score,
    roc_auc_score,roc_curve,
    precision_recall_curve,average_precision_score
)
# Classification models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.naive_bayes import GaussianNB

from sklearn.ensemble import (
    RandomForestClassifier,
    ExtraTreesClassifier,
    AdaBoostClassifier,
    GradientBoostingClassifier,
    HistGradientBoostingClassifier,
    VotingClassifier,
    StackingClassifier
)

from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# %%
models = {

    # Linear
    "Logistic Regression": LogisticRegression(max_iter=2000, random_state=1),

    # Tree
    "Decision Tree": DecisionTreeClassifier(random_state=1),

    # Naive Bayes
    "Naive Bayes": GaussianNB(),

    # Bagging Based
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=1),
    "Extra Trees": ExtraTreesClassifier(n_estimators=100, random_state=1),

    # Boosting
    "AdaBoost": AdaBoostClassifier(random_state=1),
    "Gradient Boosting": GradientBoostingClassifier(random_state=1),
    "Hist Gradient Boosting": HistGradientBoostingClassifier(random_state=1),

    # External Boosting Libraries
    "XGBoost": XGBClassifier(eval_metric='logloss', random_state=1, use_label_encoder=False),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=1),
    "LightGBM": LGBMClassifier(random_state=1)
}

# %%
from tqdm import tqdm

# %%
results = []

for name, model in tqdm(models.items()):
    model.fit(X_train, y_train)

    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    train_acc = accuracy_score(y_train, train_pred)
    test_acc  = accuracy_score(y_test, test_pred)
    f1        = f1_score(y_test, test_pred, average='weighted')
    precision = precision_score(y_test, test_pred, average='weighted')
    recall    = recall_score(y_test, test_pred, average='weighted')

    results.append({
        "Model": name,
        "Train Accuracy": train_acc,
        "Test Accuracy": test_acc,
        "F1 Score": f1,
        "Precision": precision,
        "Recall": recall
    })

    print(f"{name} done")
    print(f"Train Acc: {train_acc:.4f} | Test Acc: {test_acc:.4f} | Precision:{precision:.4} | Recall:{recall:.4} | F1: {f1:.4f}  " )
    print("_"*40)
# Out:
#   9%|▉         | 1/11 [00:02<00:22,  2.26s/it]
# Logistic Regression done
# Train Acc: 0.6780 | Test Acc: 0.6788 | Precision:0.6775 | Recall:0.6788 | F1: 0.6770
# ________________________________________
#  18%|█▊        | 2/11 [00:17<01:30, 10.08s/it]
# Decision Tree done
# Train Acc: 1.0000 | Test Acc: 0.9718 | Precision:0.9718 | Recall:0.9718 | F1: 0.9718
# ________________________________________
#  27%|██▋       | 3/11 [00:19<00:48,  6.10s/it]
# Naive Bayes done
# Train Acc: 0.6292 | Test Acc: 0.6281 | Precision:0.6411 | Recall:0.6281 | F1: 0.6276
# ________________________________________
#  36%|███▋      | 4/11 [02:31<06:30, 55.83s/it]
# Random Forest done
# Train Acc: 1.0000 | Test Acc: 0.9853 | Precision:0.9853 | Recall:0.9853 | F1: 0.9853
# ________________________________________
#  45%|████▌     | 5/11 [04:18<07:26, 74.50s/it]
# Extra Trees done
# Train Acc: 1.0000 | Test Acc: 0.9830 | Precision:0.983 | Recall:0.983 | F1: 0.9830
# ________________________________________
# ...

# %%
results_df = pd.DataFrame(results)

results_df = results_df.sort_values(by="Test Accuracy", ascending=False)

results_df.reset_index(drop=True, inplace=True)

results_df
# Out:
#                      Model  Train Accuracy  Test Accuracy  F1 Score  \
# 0            Random Forest        0.999984       0.985279  0.985280
# 1                 CatBoost        0.985165       0.984471  0.984473
# 2                  XGBoost        0.984249       0.983562  0.983563
# 3              Extra Trees        0.999996       0.982985  0.982986
# 4   Hist Gradient Boosting        0.977622       0.977696  0.977698
# 5                 LightGBM        0.974720       0.974750  0.974756
# 6            Decision Tree        0.999996       0.971835  0.971835
# 7        Gradient Boosting        0.900154       0.900827  0.900796
# 8                 AdaBoost        0.716507       0.716722  0.713355
# 9      Logistic Regression        0.678023       0.678771  0.677040
# 10             Naive Bayes        0.629229       0.628089  0.627618
#
#     Precision    Recall
# 0    0.985282  0.985279
# 1    0.984476  0.984471
# 2    0.983566  0.983562
# 3    0.982988  0.982985
# ...

# %%
plt.figure(figsize=(10,6))

df_heat = results_df.set_index("Model")[["Train Accuracy", "Test Accuracy","Precision","F1 Score","Recall"]]

sns.heatmap(df_heat, annot=True, cmap="YlGnBu", fmt=".4f")

plt.title("Model Performance Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt

df_plot = results_df.set_index("Model")

plt.figure(figsize=(12,6)) ## Train Accuracy	Test Accuracy	F1 Score	Precision	Recall

plt.plot(df_plot.index, df_plot["Train Accuracy"], marker='o', label="Train Accuracy")
plt.plot(df_plot.index, df_plot["F1 Score"], marker='o', label="F1 Score")
plt.plot(df_plot.index, df_plot["Precision"], marker='o', label="Precision")
plt.plot(df_plot.index, df_plot["Recall"], marker='o', label="Recall")

plt.xticks(rotation=45, ha="right")
plt.ylabel("Score")
plt.title("Model Comparison - All Metrics")
plt.legend()

plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

for name, model in models.items():


    cm = confusion_matrix(y_test, test_pred)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm)

    plt.figure(figsize=(4, 4))
    disp.plot(cmap="Blues", values_format='d')
    # Full classification report
    print("\nClassification Report:\n")
    print(classification_report(y_test, test_pred,target_names=['poisonous','edible'],zero_division=0)) ## e = edible, p = poisonous

    plt.title(f"Confusion Matrix - {name}")
    plt.show()
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    poisonous       0.97      0.98      0.97     84846
#       edible       0.98      0.97      0.98    102161
#
#     accuracy                           0.97    187007
#    macro avg       0.97      0.97      0.97    187007
# weighted avg       0.97      0.97      0.97    187007
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    poisonous       0.97      0.98      0.97     84846
#       edible       0.98      0.97      0.98    102161
#
#     accuracy                           0.97    187007
#    macro avg       0.97      0.97      0.97    187007
# weighted avg       0.97      0.97      0.97    187007
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    poisonous       0.97      0.98      0.97     84846
#       edible       0.98      0.97      0.98    102161
#
#     accuracy                           0.97    187007
# ...

# %%
import matplotlib.pyplot as plt

df_plot = results_df.set_index("Model")

df_plot.plot.bar(figsize=(12,6))

plt.title("Model Comparison - All Metrics")
plt.ylabel("Score")
plt.xticks(rotation=45, ha="right")
plt.ylim(0, 1)

plt.show()

# %%
import matplotlib.pyplot as plt

cols = [
    ['Train Accuracy'],
    ['Precision'],
    ['Recall'],
    ['F1 Score']
]

plt.figure(figsize=(20, 15)) ## Train Accuracy	Test Accuracy	F1 Score	Precision	Recall

for i, col in enumerate(cols):
    ax = plt.subplot(2, 2, i+1)

    results_df.set_index("Model")[col].plot.bar(ax=ax)

    ax.set_title(col[0] + ' Comparison')
    ax.set_ylim(0, 1)
    ax.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
## Receiver Operating Characteristic Curve
## TPR → True Positive Rate
## FPR → False Positive Rate
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

plt.figure(figsize=(10, 8))

for name, model in models.items():
    model.fit(X_train, y_train)

    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X_test)[:, 1]
    else:
        y_prob = model.decision_function(X_test)

    fpr, tpr, _ = roc_curve(y_test, y_prob)
    roc_auc = auc(fpr, tpr)

    plt.plot(fpr, tpr, label=f"{name} (AUC = {roc_auc:.3f})")

plt.plot([0, 1], [0, 1], 'k--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.grid()

plt.show()
# Out:
# [LightGBM] [Info] Number of positive: 409419, number of negative: 338606
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.073286 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 857
# [LightGBM] [Info] Number of data points in the train set: 748025, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.547333 -> initscore=0.189902
# [LightGBM] [Info] Start training from score 0.189902
